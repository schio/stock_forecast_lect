# %% [markdown]
# # 라이브러리 맛보기

# %% [markdown]
# #### 내장 라이브러리 사용법

# %%
import time
time.sleep(5)

# %% [markdown]
# #### 외장 라이브러리 사용법

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# #### 외장 라이브러리 설치 방법

# %%
# !pip install pandas

# %%
# !pip install shap
