# %% [markdown]
# # 1. 삼행시 지어보기
#
# 나만의 삼행시를 지어봅시다
#
# #### [지시사항]
# >1. `print`를 이용하여 삼행시를 지어봅시다
#
# #### [출력 예시]
# ```python
# 비: 비행기에 탑승하신 승객 여러분
# 행: 행복한 여행 되십시요
# 기: 기내식은 바밤바
# ```

# %%
# 지시사항 1번을 해보세요

# %% [markdown]
# ---

# %% [markdown]
# # 2. 광화문 입장료 계산하기
#
# 민수네는 함께 광화문에 방문하여 입장료를 지불하려 합니다.
# 민수네의 가족 정보를 참고하여 총 입장료를 계산하세요
#
# [민수네 가족 정보]
#
# |구분| 나이| 거주지|
# |----|---| ---|
# |아버지| 56 | 광진구 |
# |어머니|56 | 광진구 |
# |누나 | 28 | 종로구 |
# |민수 | 22 | 광진구 |
#
# [광화문 입장료]
#
# |구분| 가격|
# |----|---|
# |대인(만25세~만64세)	|3,000원|
# |소인(만24세이하)	|1,000원|
# |종로구민	|50% 할인|
#
# #### [지시사항]
# >1. `adult`, `child`에 광화문 입장료를 할당하세요
# >2. `jongrogumin_discount`에 종로구민 할인율을 할당하세요
# >3. `total_price`에 1, 2에서 선언한 변수들을 활용하여 민수네의 광화문 총 입장료를 할당하세요
#
# #### [출력 예시]
# ```python
# 민수네의 광화문 총 입장료는 8500원 입니다
# ```

# %%
# 대인 총 가격
adult =

# 소인 가격
child =

# 종로구민 할인율 적용한 대인 총 가격
jongrogumin_adult =

# 민수네의 총 입장료 계산
total_price =

print(f"민수네의 광화문 총 입장료는 {total_price}원 입니다")

# %% [markdown]
# ---

# %% [markdown]
# # 3. 홀수 짝수 구분하기
#
# `num`에 저장된 값이 홀수인지 짝수인지 구분해봅시다
#
# #### [지시사항]
# >1. line 3~4의 주석 내용을 구현하세요
#
# #### [출력 예시]
# ```python
# 11 홀수입니다
# ```
#
# #### [힌트]
# 어떤 수를 2로 나눴을 때 나머지의 값이 0이라면 그 수는 짝수입니다

# %%
num = 11

# if-else를 사용하여 num이 홀수인지 짝수인지 판단합니다
# 각 상황에 따라 알맞은 문자열을 출력합니다

# %% [markdown]
# ---

# %% [markdown]
# # 3. 여러개의 숫자 모두 홀수 짝수 구분하기
#
# `nums`에 저장된 값이 각각 홀수인지 짝수인지 구분해봅시다
#
# #### [지시사항]
# >1. line 3~5의 주석 내용을 구현하세요
#
# #### [출력 예시]
# ```python
# 1 홀수입니다
# 4 짝수입니다
# 8 짝수입니다
# 11235 홀수입니다
# 457 홀수입니다
# 235 홀수입니다
# ```
#
# #### [힌트]
# 어떤 수를 2로 나눴을 때 나머지의 값이 0이라면 그 수는 짝수입니다

# %%
nums = [1, 4, 8, 11235, 457, 235]

# for를 이용하여 nums에서 값을 차례대로 num에 저장합니다
# if-else를 사용하여num에 저장된 값이 홀수인지 짝수인지 판단합니다
# 각 상황에 따라 알맞은 문자열을 출력합니다
